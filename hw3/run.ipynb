# %%
cd /content/drive/MyDrive/CUDA/hw3
# Out:
# /content/drive/MyDrive/CUDA/hw3

# %%
# !nvcc vector_add.cu -o vector_add

# %%
# !./vector_add
# Out:
# A[0] = 0.840188
# B[0] = 0.394383
# C[0] = 1.234571

# %%
# !sudo apt-get install environment-modules
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# environment-modules is already the newest version (5.0.1-1).
# 0 upgraded, 0 newly installed, 0 to remove and 10 not upgraded.

# %%
# !source /etc/profile

# %%
# !source /etc/profile

# %%
# !module -version
# Out:
# /bin/bash: line 1: module: command not found

# %%
# !module load nsight-compute
# Out:
# /bin/bash: line 1: module: command not found

# %%
# !jsrun -n1 -a1 -c1 -g1 nv-nsight-cu-cli ./vector_add
# Out:
# /bin/bash: line 1: jsrun: command not found

# %%
# !nvprof --metrics dram_read_throughput ./vector_add
# Out:
# ======== Warning: Skipping profiling on device 0 since profiling is not supported on devices with compute capability 7.5 and higher.
#                   Use NVIDIA Nsight Compute for GPU profiling and NVIDIA Nsight Systems for GPU tracing and CPU sampling.
#                   Refer https://developer.nvidia.com/tools-overview for more details.
#
# ==4991== NVPROF is profiling process 4991, command: ./vector_add
# A[0] = 0.840188
# B[0] = 0.394383
# C[0] = 1.234571
# ==4991== Profiling application: ./vector_add
# ==4991== Profiling result:
# No events/metrics were profiled.

# %%
# !bsub -W 30 -nnodes 1 -P <allocation_ID> -Is /bin/bash
# Out:
# /bin/bash: line 1: allocation_ID: No such file or directory

# %%
# !jsrun -n1 -a1 -c1 -g1 nv-nsight-cu-cli ./vector_add
# Out:
# /bin/bash: line 1: jsrun: command not found

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
