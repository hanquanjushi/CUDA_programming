# %%
cd /content/drive/MyDrive/CUDA/hw2
# Out:
# /content/drive/MyDrive/CUDA/hw2

# %%
# !nvcc matrix_mul_shared.cu -o mat_mul

# %%
# !./mat_mul
# Out:
# Init took 0.756796 seconds.  Begin compute
# Done. Compute took 0.946394 seconds
# Success!
