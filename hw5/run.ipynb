# %%
cd /content/drive/MyDrive/CUDA/hw5
# Out:
# /content/drive/MyDrive/CUDA/hw5

# %%
# !nvcc reductions.cu -o reductions

# %%
# !./reductions
# Out:
# atomic_red kernel execution time: 29.603680 ms
# atomic sum reduction correct!
# reduce_a kernel execution time: 0.202720 ms
# reduction w/atomic sum correct!
# reduce_ws kernel execution time: 0.181440 ms
# reduction warp shuffle sum correct!

# %%
# !nvcc max_reduction.cu -o max_reductions

# %%
# !./max_reductions
# Out:
# reduction output: 5.000000, expected sum reduction output: 8388612.000000, expected max reduction output: 5.000000

# %%
# !nvcc matrix_sums.cu -o matrix_sums

# %%
# !./matrix_sums
# Out:
# atomic_red kernel execution time: 137.218338 ms
# row sums correct!
# column sums correct!

# %%
# !nvcc matrix_sums_solution.cu -o matrix_sums_solution

# %%
# !./matrix_sums_solution
# Out:
# row_sums kernel execution time: 5.755168 ms
# row sums correct!
# column sums correct!
