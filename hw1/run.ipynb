# %%
cd /content/drive/MyDrive/CUDA/hw2
# Out:
# /content/drive/MyDrive/CUDA/hw1

# %%
# !nvcc matrix_mul.cu -o matrix_mul

# %%
# !./matrix_mul
# Out:
# Init took 0.133471 seconds.  Begin compute
# Done. Compute took 0.589611 seconds
# Success!
